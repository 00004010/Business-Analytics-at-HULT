# %%
"""
HULT INTERNATIONAL BUSINESS SCHOOL
Author: Doston Yunusmatov
Group: MSBA2
"""



"""
DocString:
    
    A) Introduction:
    Hi dear player! This is the Death Valley Game Show. A player will be given a
    chance to escape the Death Valley and is able to win $100,000. Yeap, it is
    fancy. The game involvess three stages. The first two stages are guessing 
    the given object or tasks. The last round is question based where a player will 
    be asked a logic question. Here are the each stage's brief explanation:
    
    Round #1: Player guesses whether it is night or day outside. A player has
    been being kept in the valley for about 15 days so that this is the challenge 
    fro one who spent his half month in the dark areas. 
    
    Round 2: This round is fun too:). As you know player will receive $100,000
    if he/she son the game. In this stage, a player guesses the cyrrency type
    of the winner prize. Another stupid question given by the Rublex (angel in
    the Death Valley).  
    
    Round 3: This round comes up with the logic question. Really fun. Looks
    like the question is challenging but trust me extreme simple:). 

    B) Known Bugs and/or Errors:
    None.

"""

#Needed compands imported from the python packages
import time
from sys import exit
from random import randint

#Game start point-->> to fix the frequent variables repeated
def game_start():
    global player_name
    global game_host
    
    #Intriduction part--> to see the output one after one with some period between them
    #I used time command to add some period between variables
    
    print("\nHello everyone, Welcome to the Death Valley Game Show!\n")
    time.sleep(2)
    print("Today we will give a chance to players to excape the Death Valley.")
    time.sleep(2)
    
    
    input('Please press ENTER to continue-->\n')
    
    #the host name is fixed using = command
    game_host = "Slark"
    
    
    
    #I used f"""""" string to keep the str more readable, conciese and less prone to error
    
    print(f"My name is {game_host}. I will be a host in the game today and guide a player along the game stages and challenges.")
    time.sleep(3)
    print(f"""
{game_host}: Today we have a player who will be given a chance to escape the Death Valley.

{game_host}: Ladies and Gentlmen let's give him round of applauses and let's get him know closer.
""")
    time.sleep(3)
    

    #Added a new input that player is able to enter the data
    player_name = input(f'{game_host}: What is your name?\n')
    
    #Even player uses lowercases the command capitalize the first letter of the entered data
    player_name = player_name.capitalize()
    
    print(f"""
{game_host}: Hello {player_name}! Glad to see you here in the game.
""")
    time.sleep(2)
    print(f"""
{game_host}: Where are you from? \n*If USA, please enter state name.\n
""")
    player_location = input(prompt='*If USA, please enter the state name:\n')
    
    player_location = player_location.capitalize()
    
    print(f"""
{game_host}: Alright {player_name}, what is your field of interest?
""")
    time.sleep(2)
    
    #In most inputs I used \n to start from the new line
    player_hobby=input('Eg: coding, hiking, sport, etc:\n')
    
    
    print(f"""
{game_host}: Ladies and Gentlemen, please welcome {player_name} from {player_location}. 
\nHe is really passionate about {player_hobby}.\n 
\nToday he is here to escape the Death Valley and win the 100,000 <You are gonna predict the currency in Stage #2>.\n 
\n""")
    time.sleep(3)
    
    print(f"""
{game_host}: Let me give you quick guidance before you jump in the Round #1.
{game_host}: You will have 3 stages in the game and on each round you will be required to complete tasks or answer the questions.
{game_host}: I totally believe that you do best yourself to won the game and escape the Death Valley.
{game_host}: You will meet two Death Valley angles, you like them:).
{game_host}: Are you ready to start the game {player_name}?

""")

    input('If yes, please press ENTER to start the Round #1. GOOD LUCK!\n')
    
    
    round_1()
    
    #Round1: defining the round 1
def round_1():
    
    #fixing the frequent names
    angel_name="Doobi"
    print(f"{angel_name}: Welcome to the Round #1 of Death Valley Game Show!")
    time.sleep(2)
    
    input(f'{angel_name}: Slap my face and press ENTER to continue:\n')
    
    print(f"""
{angel_name}: HAHAHAH, Love to see players' wrong guess!

{angel_name}: Players has being kept in the Death Valley for about 15 days.
{angel_name}: They even dont know either it is day or night now.
{angel_name}: {player_name}, You have to guess whether it is day or night outside the valley.
{angel_name}: You will be given 2 chance to guess.
             
""")
    time.sleep(2)
    input('Slap my face and press ENTER to continue:\n')
    
    #Setting a guess limit
    guesses = 2
    
    #looping while guesses equal zero    
    while guesses > 0:
        
        #declaring the objects
        dayshift = randint(0, 1)
        print(f"""
{angel_name}: {player_name}, let's see you guess?
             1) day
             2) night

""")
        
        #giving an access to a player to predict/guess
        predict = input("> ")
        
        #if we have 1 and day in the predict output....do this
        if "1" in predict or "day" in predict:
            if dayshift == 0:
                print(f"""
{angel_name}: That's correct! How you got it {player_name}!!!

""")
                input('Slap my face and press ENTER to continue:\n')
                round_2()
                break
            #otherwise ..... do this
            else:
                print(f"""
{angel_name}: YEAH, I knew that {player_name} you are gonna fail!

""")
                #subtract 1 guess from total after single guess
                guesses -= 1
                
        #if 2 and night in the predict output....do this

        elif "2" in predict or "night" in predict:
            if dayshift == 1:
                print(f"""
{angel_name}: That's correct! How you got it {player_name}!!!

""")
                #if the guess is correct jump to the round #2
                input('Slap my face and press ENTER to continue:\n')
                round_2()
                break
                
            #if the answer is incorrect do this.... fail
            
            else:
                print(f"""
{angel_name}: YEAH, I knew that {player_name} you are gonna fail!

""")
                #subtract 1 from the total guesses
                guesses -= 1
    
    fail()
    
    #Round 2: defining round two

def round_2():
    
    #Entering element of round 2. Printing round 2 introduction
    angel1_name = "Rublex"
    print(f"""{angel1_name}: Welcome to the Round #2 {player_name}!""")
    time.sleep(2)
    
    print(f"""
{angel1_name}: This part is the most challenging one. 
               Here you have to guess the currency of amount of money which you receive if you win the game.
               Wrong guess leads you trouble: no money and unescaping the Death Valley. 
             
""")
    
    #Input to pass the next step
    input('Slap my face and press ENTER to continue:\n')
    
    
     #Total number of guesses
    guesses = 3
    
    #looping until gueeses equal zero
    while guesses > 0:
        
        #declaring the onjects/currency_type
        currency_type = randint(0, 3)
        print(f"""
{angel1_name}: {player_name}, really exciting to see your wrong guess WUAHAHAH.What is the currency type?
             1) usd
             2) euro
             3) uzbsum
             4) ukpound

""")
        #Random choice
        currency = input("> ").lower()
        
        #if 1 and usd in the random choice--> do this
        if "1" in currency or "usd" in currency:
            if currency_type == 0:
                print(f"""
{angel1_name}: Ooh wait, how you got it {player_name}? That's absolutely true!

""")
                input('Slap my face and press ENTER to continue:\n')
                round_3()
                break
                
                #otherwise go to fail. Player lose the game
            
            else:
                print(f"""
{angel1_name}: I knew that you are gonna fail! Welcome back to Death Valley {player_name}!

""")
                #Subtract 1 from the total guesses after each try completed
                guesses -= 1
                
                
         #if 2 and euro in currency -->> do this

        elif "2" in currency or "euro" in currency:
            if currency_type == 1:
                print(f"""
{angel1_name}: Ooh wait, how you got it {player_name}? That's absolutely true!

""")
                input('Slap my face and press ENTER to continue:\n')
                round_3()
                break
                
                #otherwise go to fail. Player lose the game
            
            else:
                print(f"""
{angel1_name}: I knew that you are gonna fail! Welcome back to Death Valley {player_name}!

""")
                 #Subtract 1 from the total guesses after each try completed
                guesses -= 1
                
                
            #If 2 and uzbsum in the currency-->> do this...

        elif "3" in currency or "uzbsum" in currency:
            if currency_type == 2:
                print(f"""
{angel1_name}: Ooh wait, how you got it {player_name}? That's absolutely true!

""")
                input('Slap my face and press ENTER to continue:\n')
                round_3()
                break
                
                #otherwise go to fail. Player lose the game
            
            else:
                print(f"""
{angel1_name}: I knew that you are gonna fail! Welcome back to Death Valley {player_name}!

""")
                 #Subtract 1 from the total guesses after each try completed
                guesses -= 1

                
                #if 4 and okpund in the currency-->> do this...

        elif "4" in currency or "ukpound" in currency:
            if currency_type == 3:
                print(f"""
{angel1_name}: Ooh wait, how you got it {player_name}? That's absolutely true!

""")
                input('Slap my face and press ENTER to continue:\n')
                round_3()
                break
                
                #otherwise go to fail. Player lose the game 
            
            else:
                print(f"""
{angel1_name}: I knew that you are gonna fail! Welcome back to Death Valley {player_name}!

""")
                 #Subtract 1 from the total guesses after each try completed
                guesses -= 1

            fail()
            
    #Round 3 Start point. Added elements to the introduction part-->>

def round_3():
    print(f"""
{game_host}: Nice to see yo again {player_name}! Really happy to see you in the Round #3!

{game_host}: You are almost to escape and just one step away from the winner prize!
""")
    time.sleep(2)
    
    print(f"""
{game_host}: Here I will give you a single logic question! Please, think smart!
""")
    time.sleep(2)
    
    print(f"""
    
{game_host}: Well {player_name}, here is the question.

{game_host}: What is it that if you have, you want to share me, and if you share, you do not have?
""")
    
    
    answer = input('Enter you answer:').lower()
    
    #if player enter one of these words -->> do this...
    if "a secret" in answer and "secret" in answer:
        print(f"""
        
{game_host}: Wooooow {player_name}! Good job, you got it!!!
{game_host}: You won the game, finally escaped the Death Valley. Also, you have just received the winner prize as well $100,000.
{game_host}: Congratulations {player_name}!!!
""")
        
        #finally he/she escaped the valley. Player won the game
        input('Press ENTER to escape the Death Valley-->')
        exit()
        
        #otherwise player go to fail and replay the game
        
    else:
        print(f"""
{game_host}: Ohhh noo {player_name}, your answer is wrong. That is a secret.
{game_host}: Unfortunately, you lost the game and were not able to escape the Death Valley.
""")
        fail()


    #defining the fail command. What happend if the player fails

def fail():
    print(f"""
{game_host}: Ohhhh nooooo {player_name}, you were not able to win the game and could not reach to get out of the Death Valley.
{game_host}: Hope you adopt living in the valley with Doobi and Rublex:).
""")  
    
    
    print(f"""
{game_host}: Hey {player_name}! I have just got another chance for you to escape the Death Valley.
{game_host}: Are you ready for the challenge?(Yes/No)
                          
""")
    #IF player enters yes/no the command automatically restarts from Round_1 or ends the game
    replay = input("> ")
    replay = replay.lower()
    
    #if yes -->> replay
    if replay == 'yes':
        round_1()
        
        #if no -->> end the game
    else:
        print(f"{game_host}: Thanks for playing {player_name}!")
        exit()




#End of the game if player enter yes it goes to Round_1
game_start()
# Out:
# Hello everyone, Welcome to the Death Valley Game Show!
#
# Today we will give a chance to players to excape the Death Valley
# Please press ENTER to continue-->
#
# My name is Slark. I will be a host in the game today and guide a player along the game stages and challenges
#
# Slark: Today we have a player who will be given a chance to escape the Death Valley.
#
# Slark: Ladies and Gentlmen let's give him round of applauses and let's get him know closer.
#
# Slark: What is your name?
# chase
#
# Slark: Hello Chase! Glad to see you here in the game.
#
#
# Slark: Where are you from?
# *If USA, please enter state name.
#
#
# *If USA, please enter the state name:
# cali
#
# Slark: Alright Chase, what is your field of interest?
#
# Eg: coding, hiking, sport, etc:
# codng
#
# Slark: Ladies and Gentlemen, please welcome Chase from Cali.
#
# He is really passionate about codng.
#
#
# ...

# %%
help(exit)
# Out:
# Help on built-in function exit in module sys:
#
# exit(status=None, /)
#     Exit the interpreter by raising SystemExit(status).
#
#     If the status is omitted or None, it defaults to zero (i.e., success).
#     If the status is an integer, it will be used as the system exit status.
#     If it is another kind of object, it will be printed and the system
#     exit status will be one (i.e., failure).
